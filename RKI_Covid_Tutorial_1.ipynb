# %%
import numpy as np
import pandas as pd

# %%
# %pwd
# Out:
# '/Users/uli/Documents/Work/Tutorials/RKI_Covid'

# %%
covid_path = "211203_RKI_COVID19.csv"

# %%
covid_path
# Out:
# '211203_RKI_COVID19.csv'

# %%
covid = pd.read_csv(covid_path)

# %%
covid
# Out:
#          ObjectId  IdBundesland          Bundesland            Landkreis  \
# 0               1             1  Schleswig-Holstein         SK Flensburg
# 1               2             1  Schleswig-Holstein         SK Flensburg
# 2               3             1  Schleswig-Holstein         SK Flensburg
# 3               4             1  Schleswig-Holstein         SK Flensburg
# 4               5             1  Schleswig-Holstein         SK Flensburg
# ...           ...           ...                 ...                  ...
# 3034181   3034182            16           Thüringen  LK Altenburger Land
# 3034182   3034183            16           Thüringen  LK Altenburger Land
# 3034183   3034184            16           Thüringen  LK Altenburger Land
# 3034184   3034185            16           Thüringen  LK Altenburger Land
# 3034185   3034186            16           Thüringen  LK Altenburger Land
#
#         Altersgruppe Geschlecht  AnzahlFall  AnzahlTodesfall  \
# 0            A35-A59          M           2                0
# 1            A15-A34          W           1                0
# 2            A35-A59          M           3                0
# 3            A15-A34          W           1                0
# 4            A35-A59          M           1                0
# ...              ...        ...         ...              ...
# 3034181    unbekannt  unbekannt           1                0
# 3034182    unbekannt          W           1                0
# 3034183    unbekannt          W           1                0
# 3034184    unbekannt          W           1                0
# 3034185    unbekannt          W           1                0
#
#                      Meldedatum  IdLandkreis             Datenstand  \
# 0        2021/11/17 00:00:00+00         1001  02.12.2021, 00:00 Uhr
# 1        2021/09/27 00:00:00+00         1001  02.12.2021, 00:00 Uhr
# 2        2021/11/17 00:00:00+00         1001  02.12.2021, 00:00 Uhr
# 3        2021/09/28 00:00:00+00         1001  02.12.2021, 00:00 Uhr
# 4        2021/11/17 00:00:00+00         1001  02.12.2021, 00:00 Uhr
# ...                         ...          ...                    ...
# 3034181  2021/11/30 00:00:00+00        16077  02.12.2021, 00:00 Uhr
# 3034182  2021/11/19 00:00:00+00        16077  02.12.2021, 00:00 Uhr
# 3034183  2021/11/27 00:00:00+00        16077  02.12.2021, 00:00 Uhr
# 3034184  2021/11/30 00:00:00+00        16077  02.12.2021, 00:00 Uhr
# 3034185  2021/12/01 00:00:00+00        16077  02.12.2021, 00:00 Uhr
#
#          NeuerFall  NeuerTodesfall                Refdatum  NeuGenesen  \
# 0                0              -9  2021/11/12 00:00:00+00           0
# 1                0              -9  2021/09/19 00:00:00+00           0
# 2                0              -9  2021/11/14 00:00:00+00           0
# 3                0              -9  2021/09/28 00:00:00+00           0
# 4                0              -9  2021/11/15 00:00:00+00           0
# ...            ...             ...                     ...         ...
# 3034181          1              -9  2021/11/30 00:00:00+00          -9
# 3034182          0              -9  2021/11/19 00:00:00+00          -9
# 3034183          0              -9  2021/11/27 00:00:00+00          -9
# 3034184          0              -9  2021/11/30 00:00:00+00          -9
# 3034185          1              -9  2021/12/01 00:00:00+00          -9
#
#          AnzahlGenesen  IstErkrankungsbeginn      Altersgruppe2
# 0                    2                     1  Nicht übermittelt
# 1                    1                     1  Nicht übermittelt
# 2                    3                     1  Nicht übermittelt
# 3                    1                     0  Nicht übermittelt
# 4                    1                     1  Nicht übermittelt
# ...                ...                   ...                ...
# 3034181              0                     0  Nicht übermittelt
# 3034182              0                     0  Nicht übermittelt
# 3034183              0                     0  Nicht übermittelt
# 3034184              0                     0  Nicht übermittelt
# 3034185              0                     0  Nicht übermittelt
#
# [3034186 rows x 18 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3034186 entries, 0 to 3034185
# Data columns (total 18 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ObjectId              int64
#  1   IdBundesland          int64
#  2   Bundesland            object
#  3   Landkreis             object
#  4   Altersgruppe          object
#  5   Geschlecht            object
#  6   AnzahlFall            int64
#  7   AnzahlTodesfall       int64
#  8   Meldedatum            object
#  9   IdLandkreis           int64
#  10  Datenstand            object
#  11  NeuerFall             int64
#  12  NeuerTodesfall        int64
#  13  Refdatum              object
#  14  NeuGenesen            int64
#  15  AnzahlGenesen         int64
#  16  IstErkrankungsbeginn  int64
#  17  Altersgruppe2         object
# dtypes: int64(10), object(8)
# memory usage: 416.7+ MB

# %%
covid['Bundesland']
# Out:
# 0          Schleswig-Holstein
# 1          Schleswig-Holstein
# 2          Schleswig-Holstein
# 3          Schleswig-Holstein
# 4          Schleswig-Holstein
#                   ...
# 3034181             Thüringen
# 3034182             Thüringen
# 3034183             Thüringen
# 3034184             Thüringen
# 3034185             Thüringen
# Name: Bundesland, Length: 3034186, dtype: object

# %%
covid[['Meldedatum', 'Bundesland']]
# Out:
#                      Meldedatum          Bundesland
# 0        2021/11/17 00:00:00+00  Schleswig-Holstein
# 1        2021/09/27 00:00:00+00  Schleswig-Holstein
# 2        2021/11/17 00:00:00+00  Schleswig-Holstein
# 3        2021/09/28 00:00:00+00  Schleswig-Holstein
# 4        2021/11/17 00:00:00+00  Schleswig-Holstein
# ...                         ...                 ...
# 3034181  2021/11/30 00:00:00+00           Thüringen
# 3034182  2021/11/19 00:00:00+00           Thüringen
# 3034183  2021/11/27 00:00:00+00           Thüringen
# 3034184  2021/11/30 00:00:00+00           Thüringen
# 3034185  2021/12/01 00:00:00+00           Thüringen
#
# [3034186 rows x 2 columns]

# %%
covid['Bundesland'].value_counts()
# Out:
# Bayern                    595231
# Nordrhein-Westfalen       594775
# Baden-Württemberg         418919
# Niedersachsen             229097
# Hessen                    222832
# Sachsen                   165526
# Rheinland-Pfalz           148829
# Berlin                    141319
# Thüringen                 128031
# Brandenburg               103262
# Sachsen-Anhalt             76759
# Schleswig-Holstein         74013
# Mecklenburg-Vorpommern     43740
# Hamburg                    38833
# Saarland                   34003
# Bremen                     19017
# Name: Bundesland, dtype: int64

# %%
covid['Landkreis'].value_counts()
# Out:
# SK Hamburg              38833
# SK München              28437
# SK Köln                 27740
# SK Frankfurt am Main    24313
# Region Hannover         23969
#                         ...
# SK Pirmasens             1747
# LK Wittmund              1725
# SK Emden                 1629
# SK Zweibrücken           1276
# LK Lüchow-Dannenberg     1267
# Name: Landkreis, Length: 411, dtype: int64

# %%
covid['AnzahlFall'].sum()
# Out:
# 5976524
